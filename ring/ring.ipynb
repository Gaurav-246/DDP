# %%
import gym
import numpy as np
import matplotlib.pyplot as plt
from gym import spaces
from time import sleep
from IPython.display import clear_output
# %matplotlib inline
import matplotlib.patches as patches
import torch
import torch.nn as nn
import torch.optim as optim
from torch.distributions import Normal
import torch.nn.functional as F
import pandas as pd

# %%
class MyEnv(gym.Env):
    def __init__(self, n=8):
        assert n % 4 == 0, "n must be a multiple of 4 for symmetry"
        self.n = n
        self.angles = np.linspace(0, 2*np.pi, n, endpoint=False)  # Equally spaced angles
        self.action_vectors = np.column_stack((np.cos(self.angles), np.sin(self.angles)))
        self.r_outer = 1.5
        self.r_inner = 0.75
        self.action_space = spaces.Discrete(n)
        self.observation_space = spaces.Box(low=np.array([-2.0, -2.0]), high=np.array([2.0, 2.0]))
        self.state = np.array([0.0, 0.0])
        self.step_size = 0.15
        self.env_shape = "SQUARE"
        self.trajectory = [self.state.copy()]

    def reset(self, init=False, point=np.array([0,0])):
        if not init:
            self.state = np.random.rand(2) * 4 - 2  # Anywhere in [-2,2]
        else:
            self.state = point
        self.trajectory = [self.state.copy()]
        return self.state

    def step(self, action):
        x, y = self.state
        delta_action = self.action_vectors[action] * self.step_size
        x_new = x + delta_action[0]
        y_new = y + delta_action[1]
        
        # Reflect at boundaries
        if x_new < -2:
            x_new = -4 - x_new  # Reflect from -2 boundary
        elif x_new > 2:
            x_new = 4 - x_new  # Reflect from 2 boundary
        
        if y_new < -2:
            y_new = -4 - y_new  # Reflect from -2 boundary
        elif y_new > 2:
            y_new = 4 - y_new  # Reflect from 2 boundary
        
        self.state = np.array([x_new, y_new])
        reward = 0
        done = False
        
        if self.state[0]**2 + self.state[1]**2 <= self.r_outer**2 and self.state[0]**2 + self.state[1]**2 >= self.r_inner**2:
            reward += 1.0
        elif -2.0 < x_new < 2.0 and -2.0 < y_new < 2.0:
            reward -= 1.0
        else:
            reward -= 2.0
        
        self.trajectory.append(self.state.copy())
        return self.state, reward, done, {}

    def render(self, ax=None):
        if ax is None:
            fig, ax = plt.subplots(figsize=(6,6))
        x_coords = [point[0] for point in self.trajectory]
        y_coords = [point[1] for point in self.trajectory]
        
        square_2 = patches.Rectangle((-2, -2), 4, 4, linewidth=1, edgecolor='k', linestyle='--', facecolor='gray', alpha=0.7)
        ax.add_patch(square_2)
        outer_circle = patches.Circle((0, 0), self.r_outer, linewidth=1, edgecolor='k',
                                  facecolor='gold', alpha=0.6)
        inner_circle = patches.Circle((0, 0), self.r_inner, linewidth=1, edgecolor='k',facecolor='gray', alpha=0.8)

        ax.add_patch(outer_circle)
        ax.add_patch(inner_circle)

        # Masking inner circle out by drawing it in background color (optional)
        # ax.add_patch(patches.Circle((0, 0), self.r_inner, facecolor='gray', edgecolor='gray', alpha=0.7))
        
        ax.plot(x_coords, y_coords, label='Trajectory')
        ax.scatter(x_coords[-1], y_coords[-1], color='red', label='Agent')
        ax.scatter(x_coords[0], y_coords[0], color='black', label='Initial Point')
        ax.set_xlim(-3, 3)
        ax.set_ylim(-3, 3)
        ax.set_title("Environment")
        ax.set_xlabel("X axis")
        ax.set_ylabel("Y axis")
        ax.legend()

# %%
env = MyEnv(n=16)
state = env.reset()
total_reward = 0
for i in range(10):
    action = env.action_space.sample()  # Random direction
    state, reward, done, _ = env.step(action)
    total_reward += reward
env.render()
plt.show()
print("Reward : ", total_reward)
# Out:
# Reward :  10.0

# %%
class Shared_model(nn.Module):
    def __init__(self, state_dim, action_dim, hidden_size=64):
        super(Shared_model, self).__init__()
        self.fc1 = nn.Linear(state_dim, hidden_size)
        self.fc2 = nn.Linear(hidden_size, hidden_size)
        self.fc3 = nn.Linear(hidden_size, hidden_size)
        self.action_dim = action_dim
        self.actor = nn.Linear(hidden_size, action_dim)  # Mean of the action distribution
        self.value = nn.Linear(hidden_size, 1)  # Output a single value representing state value
        self.beta_sigmoid = 10
        self.init_weights()
        
    def init_weights(self):
        # Xavier Initialization for fc1 and fc2
        nn.init.xavier_uniform_(self.fc1.weight)
        nn.init.xavier_uniform_(self.fc2.weight)
        nn.init.xavier_uniform_(self.fc3.weight)
        nn.init.xavier_uniform_(self.actor.weight)
        nn.init.xavier_uniform_(self.value.weight)

        # Set biases for positive value output
        nn.init.constant_(self.fc1.bias, 0.1)
        nn.init.constant_(self.fc2.bias, 0.1)
        nn.init.constant_(self.fc3.bias, 0.1)
        nn.init.constant_(self.actor.bias, 0.0)  
        nn.init.constant_(self.value.bias, 1.0)
    
    def forward(self, state, threshold=0):
        x = torch.relu(self.fc1(state))
        x = torch.relu(self.fc2(x))
        val = self.value(x)
        action_d1 = self.actor(torch.relu(self.fc3(x)))
        action_d2 = torch.rand(self.action_dim)
        sigmoid_ = 1 / (1 + torch.exp(-self.beta_sigmoid * (val - threshold)))
        action = F.softmax((1-sigmoid_) * action_d1 + sigmoid_ * action_d2, dim=-1)
        return action, val

# %%
def random_point_in_circle(radius=1.0):
    angle = np.random.uniform(0, 2 * np.pi)
    r = radius * np.sqrt(np.random.uniform(0, 1))  # sqrt for uniform area density
    x = r * np.cos(angle)
    y = r * np.sin(angle)
    return np.array([x, y])

def gen_point_here(r_inner, r_outer):
    while True:
        x,y = np.random.rand(2)
        if x**2 + y**2 <= r_outer**2 and x**2 + y**2 >= r_inner**2:
            return np.array([x,y])

# %%
def actor_critic_bg(model_shared, episodes, max_steps=100, gamma=0.99, lr_shared=1e-5, n=8):
    optimizer_shared = optim.Adam(model_shared.parameters(), lr=lr_shared)
    stats = {'Total Loss': [], 'Returns': [], 'a_loss':[], 'c_loss':[]}
    env = MyEnv(n)
    for episode in range(1, episodes + 1):
        state = env.reset()
        state = state = np.squeeze(np.column_stack((np.linalg.norm(state), np.arctan2(state[1], state[0]))))
        ep_return = 0
        done = False
        step_count = 0
        threshold = 0
        while not done and step_count < max_steps:
            state_tensor = torch.FloatTensor(state)
            action_probs, val = model_shared(state_tensor, threshold)
            action_prob, action = torch.max(action_probs, dim=0)       
            next_state, reward, done, _ = env.step(action)
            next_value = model_shared(torch.FloatTensor(state), threshold)[1]
            td_target = reward + gamma * next_value * (1 - done)
            advantage = td_target - val
            critic_loss = F.mse_loss(val, td_target.detach())
            log_prob = torch.log(action_prob)
            actor_loss = -log_prob * advantage.detach()
            total_loss = actor_loss + critic_loss
            optimizer_shared.zero_grad()
            total_loss.backward()
            optimizer_shared.step()
            state = next_state
            ep_return += reward
            step_count += 1
        if episode%100==0:
            fig, axs = plt.subplots(1, 2, figsize=(8,4))
            # First plot: Value Function
            x = np.arange(-2, 2.01, 0.01)
            y = np.arange(2, -2.01, -0.01)
            xx, yy = np.meshgrid(x, y)
            grid_points = np.column_stack([xx.ravel(), yy.ravel()])
            y_pred = np.squeeze(model_shared(torch.FloatTensor(grid_points))[1].detach().numpy()).reshape(401, 401)
            im = axs[0].imshow(y_pred, extent=[-2, 2, -2, 2])
            axs[0].set_title('Value Function')
            fig.colorbar(im, ax=axs[0])
            num_actions, grid_size = 16, 30
            angles = np.linspace(0, 2 * np.pi, num_actions, endpoint=False)
            action_vectors = np.stack((np.cos(angles), np.sin(angles)), axis=1)
            x, y = np.linspace(-2, 2, grid_size), np.linspace(-2, 2, grid_size)
            X, Y = np.meshgrid(x, y)
            U, V = np.zeros_like(X), np.zeros_like(Y)
            for i in range(grid_size):
                for j in range(grid_size):
                    state = np.array([X[i, j], Y[i, j]])
                    action_probs, _ = model_shared(torch.FloatTensor(state), threshold)
                    action = torch.argmax(action_probs).item()
                    U[i, j], V[i, j] = action_vectors[action]
            axs[1].quiver(X, Y, U, V, angles='xy')
            axs[1].set(title="RL Agent's Action Direction Field", xlabel='State Dimension 1', ylabel='State Dimension 2')
            axs[1].set_aspect('equal')
            axs[1].grid(True)
            plt.tight_layout()
            plt.show()

        stats['Total Loss'].append(total_loss.item())
        stats['a_loss'].append(actor_loss.item())
        stats['c_loss'].append(critic_loss.item())
        stats['Returns'].append(ep_return)
        print(f"Episode {episode}: Total Loss: {total_loss.item():.4f}, Actor Loss: {actor_loss.item():.4f}, Critic Loss: {critic_loss.item():.4f}, Return: {ep_return}, Steps: {step_count}")
    return stats

# %%
input_size = 2
num_actions = 16
# model_shared = Shared_model(input_size, num_actions, hidden_size=64)
num_episodes = 2000
stats = actor_critic_bg(model_shared, num_episodes, lr_shared=1e-5, max_steps=100, gamma=0.1, n=num_actions)
# Out:
# Episode 1: Total Loss: 0.1363, Actor Loss: -0.1186, Critic Loss: 0.2548, Return: -6.0, Steps: 100
# Episode 2: Total Loss: 1.6605, Actor Loss: 0.7451, Critic Loss: 0.9154, Return: -14.0, Steps: 100
# Episode 3: Total Loss: 1.7770, Actor Loss: 0.9689, Critic Loss: 0.8081, Return: 20.0, Steps: 100
# Episode 4: Total Loss: 0.3830, Actor Loss: -0.2769, Critic Loss: 0.6599, Return: -24.0, Steps: 100
# Episode 5: Total Loss: -0.9046, Actor Loss: -2.4977, Critic Loss: 1.5931, Return: -42.0, Steps: 100
# Episode 6: Total Loss: 1.1962, Actor Loss: 0.1609, Critic Loss: 1.0353, Return: -28.0, Steps: 100
# Episode 7: Total Loss: 1.5689, Actor Loss: 0.5688, Critic Loss: 1.0001, Return: -24.0, Steps: 100
# Episode 8: Total Loss: 0.0881, Actor Loss: -0.0782, Critic Loss: 0.1663, Return: 10.0, Steps: 100
# Episode 9: Total Loss: 1.8080, Actor Loss: 1.0286, Critic Loss: 0.7794, Return: -38.0, Steps: 100
# Episode 10: Total Loss: 0.0341, Actor Loss: -0.0015, Critic Loss: 0.0356, Return: 28.0, Steps: 100
# Episode 37: Total Loss: 0.1234, Actor Loss: -0.0020, Critic Loss: 0.1254, Return: 40.0, Steps: 100
# Episode 38: Total Loss: 1.1799, Actor Loss: 0.2177, Critic Loss: 0.9622, Return: 40.0, Steps: 100
# Episode 39: Total Loss: 1.2474, Actor Loss: 0.2804, Critic Loss: 0.9670, Return: -28.0, Steps: 100
# Episode 40: Total Loss: 0.0263, Actor Loss: -0.0218, Critic Loss: 0.0480, Return: 8.0, Steps: 100
# Episode 41: Total Loss: 1.6773, Actor Loss: 0.2188, Critic Loss: 1.4585, Return: -24.0, Steps: 100
# Episode 42: Total Loss: 0.0224, Actor Loss: -0.0083, Critic Loss: 0.0307, Return: -38.0, Steps: 100
# Episode 43: Total Loss: 1.7855, Actor Loss: 0.7360, Critic Loss: 1.0495, Return: 8.0, Steps: 100
# Episode 44: Total Loss: 0.1083, Actor Loss: -0.0023, Critic Loss: 0.1105, Return: -54.0, Steps: 100
# Episode 45: Total Loss: 1.4744, Actor Loss: 0.0179, Critic Loss: 1.4564, Return: 22.0, Steps: 100
# Episode 46: Total Loss: 0.0837, Actor Loss: -0.0022, Critic Loss: 0.0860, Return: -2.0, Steps: 100
# Episode 47: Total Loss: 0.2270, Actor Loss: -0.2685, Critic Loss: 0.4956, Return: 22.0, Steps: 100
# Episode 48: Total Loss: 0.4908, Actor Loss: -0.0376, Critic Loss: 0.5283, Return: -24.0, Steps: 100
# Episode 49: Total Loss: 0.2584, Actor Loss: -0.1335, Critic Loss: 0.3919, Return: 26.0, Steps: 100
# Episode 50: Total Loss: 0.0499, Actor Loss: -0.0102, Critic Loss: 0.0601, Return: -18.0, Steps: 100
# Episode 51: Total Loss: -1.3837, Actor Loss: -3.0180, Critic Loss: 1.6343, Return: -96.0, Steps: 100
# Episode 52: Total Loss: 1.6998, Actor Loss: 0.2553, Critic Loss: 1.4445, Return: 6.0, Steps: 100
# Episode 53: Total Loss: 0.4233, Actor Loss: -0.1492, Critic Loss: 0.5725, Return: -4.0, Steps: 100
# Episode 54: Total Loss: 1.6917, Actor Loss: 0.7072, Critic Loss: 0.9845, Return: 18.0, Steps: 100
# Episode 55: Total Loss: -0.0000, Actor Loss: -0.0006, Critic Loss: 0.0006, Return: 20.0, Steps: 100
# Episode 56: Total Loss: 2.0302, Actor Loss: 1.3362, Critic Loss: 0.6940, Return: -6.0, Steps: 100
# Episode 57: Total Loss: 1.9726, Actor Loss: 0.5786, Critic Loss: 1.3940, Return: -34.0, Steps: 100
# Episode 58: Total Loss: 1.7400, Actor Loss: 0.6220, Critic Loss: 1.1180, Return: 16.0, Steps: 100
# Episode 59: Total Loss: -1.0099, Actor Loss: -2.7401, Critic Loss: 1.7302, Return: -90.0, Steps: 100
# Episode 60: Total Loss: -0.8542, Actor Loss: -2.2139, Critic Loss: 1.3596, Return: -26.0, Steps: 100
# Episode 61: Total Loss: 0.0421, Actor Loss: -0.0066, Critic Loss: 0.0487, Return: 24.0, Steps: 100
# Episode 810: Total Loss: 1.2677, Actor Loss: 0.1418, Critic Loss: 1.1259, Return: 16.0, Steps: 100
# Episode 811: Total Loss: 1.2233, Actor Loss: 0.1019, Critic Loss: 1.1214, Return: -38.0, Steps: 100
# Episode 812: Total Loss: 0.1827, Actor Loss: -0.0063, Critic Loss: 0.1890, Return: 2.0, Steps: 100
# Episode 813: Total Loss: 1.2166, Actor Loss: 0.0363, Critic Loss: 1.1802, Return: 8.0, Steps: 100
# Episode 814: Total Loss: 1.0403, Actor Loss: 0.0110, Critic Loss: 1.0292, Return: -4.0, Steps: 100
# Episode 815: Total Loss: 0.0017, Actor Loss: -0.0002, Critic Loss: 0.0019, Return: -32.0, Steps: 100
# Episode 816: Total Loss: 1.4266, Actor Loss: 0.6878, Critic Loss: 0.7388, Return: -2.0, Steps: 100
# Episode 817: Total Loss: 0.0146, Actor Loss: -0.0002, Critic Loss: 0.0148, Return: -32.0, Steps: 100
# Episode 818: Total Loss: 1.4539, Actor Loss: 0.4170, Critic Loss: 1.0368, Return: -32.0, Steps: 100
# Episode 819: Total Loss: 0.1446, Actor Loss: -0.0375, Critic Loss: 0.1821, Return: -28.0, Steps: 100
# Episode 820: Total Loss: 0.0053, Actor Loss: 0.0000, Critic Loss: 0.0053, Return: -14.0, Steps: 100
# Episode 821: Total Loss: 1.3284, Actor Loss: 0.0709, Critic Loss: 1.2575, Return: 0.0, Steps: 100
# Episode 822: Total Loss: 0.4012, Actor Loss: -0.0128, Critic Loss: 0.4140, Return: -28.0, Steps: 100
# Episode 823: Total Loss: 0.0291, Actor Loss: -0.0001, Critic Loss: 0.0292, Return: -54.0, Steps: 100
# Episode 824: Total Loss: 0.0024, Actor Loss: -0.0015, Critic Loss: 0.0039, Return: -40.0, Steps: 100
# Episode 825: Total Loss: 1.2339, Actor Loss: 0.1838, Critic Loss: 1.0501, Return: 2.0, Steps: 100
# Episode 826: Total Loss: 0.0062, Actor Loss: 0.0000, Critic Loss: 0.0062, Return: 24.0, Steps: 100
# Episode 827: Total Loss: 1.4301, Actor Loss: 0.2960, Critic Loss: 1.1341, Return: 8.0, Steps: 100
# Episode 828: Total Loss: 1.8604, Actor Loss: 0.6973, Critic Loss: 1.1631, Return: 14.0, Steps: 100
# Episode 829: Total Loss: 0.1974, Actor Loss: -0.0157, Critic Loss: 0.2131, Return: 24.0, Steps: 100
# Episode 830: Total Loss: 0.2052, Actor Loss: -0.0289, Critic Loss: 0.2341, Return: -8.0, Steps: 100
# Episode 831: Total Loss: 1.5653, Actor Loss: 0.7313, Critic Loss: 0.8339, Return: 18.0, Steps: 100
# Episode 832: Total Loss: 1.0712, Actor Loss: 0.0118, Critic Loss: 1.0595, Return: 2.0, Steps: 100
# Episode 833: Total Loss: 1.3955, Actor Loss: 0.6816, Critic Loss: 0.7139, Return: -14.0, Steps: 100
# Episode 834: Total Loss: 0.0538, Actor Loss: -0.0184, Critic Loss: 0.0722, Return: -6.0, Steps: 100
# Episode 835: Total Loss: 0.0193, Actor Loss: -0.0002, Critic Loss: 0.0195, Return: -16.0, Steps: 100
# Episode 861: Total Loss: -1.5334, Actor Loss: -3.3111, Critic Loss: 1.7777, Return: -62.0, Steps: 100
# Episode 862: Total Loss: 0.0276, Actor Loss: -0.0003, Critic Loss: 0.0280, Return: 18.0, Steps: 100
# Episode 863: Total Loss: 1.2231, Actor Loss: 0.0007, Critic Loss: 1.2224, Return: -4.0, Steps: 100
# Episode 864: Total Loss: 0.1821, Actor Loss: -0.0716, Critic Loss: 0.2537, Return: 10.0, Steps: 100
# Episode 865: Total Loss: 0.0226, Actor Loss: -0.0100, Critic Loss: 0.0326, Return: 10.0, Steps: 100
# Episode 866: Total Loss: 1.0360, Actor Loss: 0.2207, Critic Loss: 0.8153, Return: -8.0, Steps: 100
# Episode 867: Total Loss: 0.3453, Actor Loss: -0.0279, Critic Loss: 0.3732, Return: -26.0, Steps: 100
# Episode 868: Total Loss: -1.2435, Actor Loss: -3.1243, Critic Loss: 1.8808, Return: -12.0, Steps: 100
# Episode 869: Total Loss: 1.2112, Actor Loss: 0.2028, Critic Loss: 1.0084, Return: -16.0, Steps: 100
# Episode 870: Total Loss: 1.7494, Actor Loss: 0.5061, Critic Loss: 1.2433, Return: -16.0, Steps: 100
# Episode 871: Total Loss: 1.6391, Actor Loss: 0.8856, Critic Loss: 0.7535, Return: -12.0, Steps: 100
# Episode 872: Total Loss: 0.0519, Actor Loss: -0.0000, Critic Loss: 0.0519, Return: -56.0, Steps: 100
# Episode 873: Total Loss: -0.6875, Actor Loss: -2.2860, Critic Loss: 1.5985, Return: 2.0, Steps: 100
# Episode 874: Total Loss: 1.6601, Actor Loss: 0.7994, Critic Loss: 0.8607, Return: 10.0, Steps: 100
# Episode 875: Total Loss: 0.0010, Actor Loss: -0.0001, Critic Loss: 0.0010, Return: 2.0, Steps: 100
# Episode 876: Total Loss: -0.3050, Actor Loss: -1.8077, Critic Loss: 1.5027, Return: -2.0, Steps: 100
# Episode 877: Total Loss: 0.4621, Actor Loss: -0.0009, Critic Loss: 0.4629, Return: -8.0, Steps: 100
# Episode 878: Total Loss: 0.0352, Actor Loss: -0.0003, Critic Loss: 0.0355, Return: -34.0, Steps: 100
# Episode 879: Total Loss: 1.5734, Actor Loss: 0.3109, Critic Loss: 1.2625, Return: 0.0, Steps: 100
# Episode 880: Total Loss: 1.3420, Actor Loss: 0.3980, Critic Loss: 0.9440, Return: -22.0, Steps: 100
# Episode 881: Total Loss: 1.5053, Actor Loss: 0.2057, Critic Loss: 1.2997, Return: 20.0, Steps: 100
# Episode 882: Total Loss: 1.3789, Actor Loss: 0.0024, Critic Loss: 1.3765, Return: 4.0, Steps: 100
# Episode 883: Total Loss: 0.0220, Actor Loss: -0.0048, Critic Loss: 0.0268, Return: 6.0, Steps: 100
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[119], line 5
#       3 # model_shared = Shared_model(input_size, num_actions, hidden_size=64)
#       4 num_episodes = 2000
# ----> 5 stats = actor_critic_bg(model_shared, num_episodes, lr_shared=1e-5, max_steps=100, gamma=0.1, n=num_actions)
#
# Cell In[115], line 25, in actor_critic_bg(model_shared, episodes, max_steps, gamma, lr_shared, n)
#      23 total_loss = actor_loss + critic_loss
#      24 optimizer_shared.zero_grad()
# ---> 25 total_loss.backward()
#      26 optimizer_shared.step()
#      27 state = next_state
#
# File c:\Users\g\anaconda3\envs\torch\lib\site-packages\torch\_tensor.py:581, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     571 if has_torch_function_unary(self):
#     572     return handle_torch_function(
#     573         Tensor.backward,
#     574         (self,),
#    (...)
#     579         inputs=inputs,
#     580     )
# --> 581 torch.autograd.backward(
#     582     self, gradient, retain_graph, create_graph, inputs=inputs
#     583 )
#
# File c:\Users\g\anaconda3\envs\torch\lib\site-packages\torch\autograd\__init__.py:347, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     342     retain_graph = create_graph
#     344 # The reason we repeat the same comment below is that
#     345 # some Python versions print out the first line of a multi-line function
#     346 # calls in the traceback and some print out the last line
# --> 347 _engine_run_backward(
#     348     tensors,
#     349     grad_tensors_,
#     350     retain_graph,
#     351     create_graph,
#     352     inputs,
#     353     allow_unreachable=True,
#     354     accumulate_grad=True,
#     355 )
#
# File c:\Users\g\anaconda3\envs\torch\lib\site-packages\torch\autograd\graph.py:825, in _engine_run_backward(t_outputs, *args, **kwargs)
#     823     unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     824 try:
# --> 825     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     826         t_outputs, *args, **kwargs
#     827     )  # Calls into the C++ engine to run the backward pass
#     828 finally:
#     829     if attach_logging_hooks:
#
# KeyboardInterrupt:

# %%
model_shared = Shared_model(2, 16, hidden_size=64)
model_shared.load_state_dict(torch.load('true_bg_ring.pth'))
# Out:
# C:\Users\g\AppData\Local\Temp\ipykernel_4236\938721157.py:2: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model_shared.load_state_dict(torch.load('true_bg_ring.pth'))
# <All keys matched successfully>

# %%
env = MyEnv(16)
state = env.reset()
done = False
total_reward = 0
max_steps = 20000
steps = 0
thresh = 0.0


while not done and steps < max_steps:
    if steps % 1000 ==0:
        clear_output(wait=True)
        env.render()
        plt.show()
        sleep(0.01)
    state_tensor = torch.FloatTensor(state)
    action_probs, val = model_shared(state_tensor, thresh)
    action_prob, action = torch.max(action_probs, dim=0)            
    state, reward, done, _ = env.step(action)
    total_reward += reward
    if steps >= max_steps:
        break
    steps+=1
print(f"Total reward in human mode: {total_reward}")
# Out:
# Total reward in human mode: 7152.0

# %%
env = MyEnv(n=16)
state = env.reset(init=True, point=np.array([-1.7, -1.7]))
done = False
total_reward = 0
max_steps = 100000
steps = 0
thresh = 0.0

while not done and steps < max_steps:
    state_tensor = torch.FloatTensor(state)
    action_probs, val = model_shared(state_tensor, thresh)
    action_prob, action = torch.max(action_probs, dim=0)            
    state, reward, done, _ = env.step(action)
    total_reward += reward
    if steps >= max_steps:
        break
    steps+=1
    if steps==1000 or steps==10000:
        env.render()
        plt.show()
env.render()

# %%
x = np.arange(-2, 2.01, 0.01)
y = np.arange(2, -2.01, -0.01)
xx, yy = np.meshgrid(x, y)
grid_points = np.column_stack([xx.ravel(), yy.ravel()])
y_pred = np.squeeze(model_shared(torch.FloatTensor(grid_points))[1].detach().numpy()).reshape(401, 401)
plt.title('Value Function')
plt.imshow(y_pred, extent=[-2,2,-2,2])
plt.colorbar()

# %%
num_actions = 16
angles = np.linspace(0, 2 * np.pi, num_actions, endpoint=False)
action_vectors = np.stack((np.cos(angles), np.sin(angles)), axis=1)

# 2. Create a grid over the 2D space (e.g., from -1 to 1)
grid_size = 30
x = np.linspace(-3, 3, grid_size)
y = np.linspace(-3, 3, grid_size)
X, Y = np.meshgrid(x, y)

# 3. Compute the agent's action at each point
U = np.zeros_like(X)  # x-component of vector
V = np.zeros_like(Y)  # y-component of vector

for i in range(grid_size):
    for j in range(grid_size):
        state = np.array([X[i, j], Y[i, j]])  # Modify if your state is higher-dimensional
        action_probs, val = model_shared(torch.FloatTensor(state),threshold=0)
        action_prob, action = torch.max(action_probs, dim=0)
        action_idx = action.item()
        direction = action_vectors[action_idx]
        U[i, j] = direction[0]
        V[i, j] = direction[1]

# 4. Plot using quiver
plt.figure(figsize=(8,8))
plt.quiver(X, Y, U, V, angles='xy')
plt.title("Agent's Action Direction Field")
plt.xlabel("State Dimension 1")
plt.ylabel("State Dimension 2")
plt.axis('equal')
plt.grid(True)
plt.show()
